# %% [markdown]
# # Домашнее задание к лекции "Основы Python"

# %% [markdown]
# ## Задание 1

# %%
phrase_1 = 'В Люксембурге три государственных языка — немецкий, французский и люксембургский'

# %%
phrase_2 = 'Люксембург, находящийся на перекрестке важных путей, в междуречье Мозеля и Мааса, всегда был важной экономической и стратегической областью'

# %%
if len(phrase_1)>len(phrase_2):
    print('Результат: Фраза 1 длиннее фразы 2')
if len(phrase_1)<len(phrase_2):
    print('Результат: Фраза 2 длиннее фразы 1')
else: print('Результат: Фразы равной длины')
# Out:
# Результат: Фраза 2 длиннее фразы 1

# %% [markdown]
# ## Задание 2

# %%
year = 2013
if year % 4 == 0 and year % 100 != 0:
    print('Результат: Високосный год')
elif year % 4 == 0 and year % 100 ==0 and year % 400 ==0:
    print('Результат: Високосный год')
else: print('Результат: Обычный год')
# Out:
# Результат: Обычный год

# %% [markdown]
# ## Задание 3

# %%
day = int(input('Введите день: '))
month = str(input('Введите месяц: '))
if (month == 'январь' and 20 <= day <= 31) or (month =='февраль' and 1 <= day <= 19):
    print('Ваш знак зодиака: Водолей')
elif (month == 'февраль' and 20 <= day <= 28) or (month =='март' and 1 <= day <= 20):
    print('Ваш знак зодиака: Рыбы')
elif (month == 'март' and 21 <= day <= 31) or (month =='апрель' and 1 <= day <= 19):
    print('Ваш знак зодиака: Овен')
elif (month == 'апрель' and 20 <= day <= 30) or (month =='май' and 1 <= day <= 20):
    print('Ваш знак зодиака: Телец')
elif (month == 'май' and 21 <= day <= 31) or (month =='июнь' and 1 <= day <= 20):
    print('Ваш знак зодиака: Близнецы')
elif (month == 'июнь' and 21 <= day <= 30) or (month =='июль' and 1 <= day <= 22):
    print('Ваш знак зодиака: Рак')
elif (month == 'июль' and 23 <= day <= 31) or (month =='август' and 1 <= day <= 22):
    print('Ваш знак зодиака: Лев')
elif (month == 'август' and 23 <= day <= 31) or (month =='сентябрь' and 1 <= day <= 22):
    print('Ваш знак зодиака: Дева')
elif (month == 'сентябрь' and 23 <= day <= 30) or (month =='октябрь' and 1 <= day <= 23):
    print('Ваш знак зодиака: Весы')
elif (month == 'октябрь' and 24 <= day <= 31) or (month =='ноябрь' and 1 <= day <= 22):
    print('Ваш знак зодиака: Скорпион')
elif (month == 'ноябрь' and 23 <= day <= 30) or (month =='декабрь' and 1 <= day <= 21):
    print('Ваш знак зодиака: Стрелец')
elif (month == 'декабрь' and 21 <= day <= 31) or (month =='январь' and 1 <= day <= 19):
    print('Ваш знак зодиака: Козерог')
else: print('Неверный формат даты')
# Out:
# Введите день: 2
# Введите месяц: октябрь
# Ваш знак зодиака: Весы

# %% [markdown]
# ## Задание 4

# %%
width = 45
length = 201
height = 40
if width < 15 and length < 15 and height < 15:
    print('Коробка №1')
elif (15 < width < 50 or 15 < length < 50 or 15 < height < 50) and length <= 200:
    print('Коробка №2')
elif length > 200:
    print('Упаковка для лыж')
else: print('Стандартная коробка №3')
# Out:
# Упаковка для лыж

# %% [markdown]
# ## Задание 5 (необязательное)

# %%
number = 123321
type(number)
if int(str(number)[0])+int(str(number)[1])+int(str(number)[2]) == int(str(number)[3])+int(str(number)[4])+int(str(number)[5]):
    print('Результат: Счастливый билет')
else: print('Результат: Несчастливый билет')
# Out:
# Результат: Счастливый билет

# %% [markdown]
# ## Задание 6 (необязательное)

# %%
import math

# %%
figure_input = str(input('Введите тип фигуры: '))
if figure_input == 'круг':
    circle_area = math.pi*(int(input('Введите радиус круга: ')))**2
    print('Площадь круга:', circle_area)
if figure_input == 'прямоугольник':
    rectangle_area = int(input('Введите длину стороны А: '))*int(input('Введите длину стороны B: '))
    print('Площадь прямоугольника:', rectangle_area)
# Out:
# Введите тип фигуры: круг
# Введите радиус круга: 3
# Площадь круга: 28.274333882308138
